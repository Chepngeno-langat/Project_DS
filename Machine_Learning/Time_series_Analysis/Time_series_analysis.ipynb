# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('MARUTI.csv')
maruti_df = pd.read_csv('MARUTI.csv')
maruti_df.head()
# Out:
#          Date  Symbol Series  Prev Close    Open    High     Low   Last  \
# 0  2003-07-09  MARUTI     EQ      125.00  164.90  170.40  155.00  164.0
# 1  2003-07-10  MARUTI     EQ      164.30  167.00  168.70  164.50  167.0
# 2  2003-07-11  MARUTI     EQ      167.00  167.75  174.85  166.25  173.6
# 3  2003-07-14  MARUTI     EQ      173.35  174.25  179.25  174.25  178.6
# 4  2003-07-15  MARUTI     EQ      177.95  200.00  200.00  173.00  176.3
#
#     Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  164.30  165.95  35164283  5.835528e+14     NaN           8537695.0
# 1  167.00  166.74  10464179  1.744820e+14     NaN           4363947.0
# 2  173.35  172.45  11740117  2.024622e+14     NaN           3014852.0
# 3  177.95  177.91   5982324  1.064313e+14     NaN           1949217.0
# 4  176.20  176.88   6173689  1.092001e+14     NaN           1307694.0
#
#    %Deliverble
# 0       0.2428
# 1       0.4170
# 2       0.2568
# 3       0.3258
# 4       0.2118

# %%
maruti_df.shape
# Out:
# (4427, 15)

# %%
maruti_df.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
maruti_df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  4427.000000  4427.000000  4427.000000  4427.000000  4427.000000
# mean   2923.575085  2927.873074  2962.918432  2889.128066  2924.651604
# std    2740.532701  2745.541243  2769.986950  2715.403311  2740.438635
# min     125.000000   164.000000   168.700000   155.000000   164.000000
# 25%     822.525000   825.100000   840.000000   806.300000   823.025000
# 50%    1412.450000  1414.000000  1432.000000  1390.350000  1412.200000
# 75%    5097.350000  5100.000000  5192.050000  5006.025000  5104.500000
# max    9832.450000  9966.000000  9996.400000  9725.000000  9846.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  4427.000000  4427.000000  4.427000e+03  4.427000e+03    2456.000000
# mean   2925.005094  2926.480642  1.194661e+06  2.395307e+14   55428.511808
# std    2740.723734  2742.675329  1.637957e+06  2.935761e+14   44405.350898
# ...

# %%
maruti_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4427 entries, 0 to 4426
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                4427 non-null   object
#  1   Symbol              4427 non-null   object
#  2   Series              4427 non-null   object
#  3   Prev Close          4427 non-null   float64
#  4   Open                4427 non-null   float64
#  5   High                4427 non-null   float64
#  6   Low                 4427 non-null   float64
#  7   Last                4427 non-null   float64
#  8   Close               4427 non-null   float64
#  9   VWAP                4427 non-null   float64
#  10  Volume              4427 non-null   int64
#  11  Turnover            4427 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4426 non-null   float64
#  14  %Deliverble         4426 non-null   float64
# ...

# %%
# Convert date to datetime
maruti_df['Date'] = maruti_df['Date'].apply(pd.to_datetime)
maruti_df.set_index('Date', inplace=True)
maruti_df
# Out:
#             Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2003-07-09  MARUTI     EQ      125.00   164.90   170.40   155.00   164.00
# 2003-07-10  MARUTI     EQ      164.30   167.00   168.70   164.50   167.00
# 2003-07-11  MARUTI     EQ      167.00   167.75   174.85   166.25   173.60
# 2003-07-14  MARUTI     EQ      173.35   174.25   179.25   174.25   178.60
# 2003-07-15  MARUTI     EQ      177.95   200.00   200.00   173.00   176.30
# ...            ...    ...         ...      ...      ...      ...      ...
# 2021-04-26  MARUTI     EQ     6676.10  6690.20  6789.00  6600.00  6645.00
# 2021-04-27  MARUTI     EQ     6638.90  6669.95  6709.00  6542.00  6552.00
# 2021-04-28  MARUTI     EQ     6568.75  6568.75  6650.00  6545.00  6581.00
# 2021-04-29  MARUTI     EQ     6573.80  6635.00  6647.45  6552.00  6562.00
# 2021-04-30  MARUTI     EQ     6565.65  6537.10  6559.60  6421.00  6438.35
#
#               Close     VWAP    Volume      Turnover    Trades  \
# Date
# ...

# %%
maruti_df['Symbol'].value_counts()
# Out:
# Symbol
# MARUTI    4427
# Name: count, dtype: int64

# %%
maruti_df.isnull().sum()
# Out:
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                1971
# Deliverable Volume       1
# %Deliverble              1
# dtype: int64

# %%
maruti_df = maruti_df.drop(columns=['Symbol', 'Series', 'Trades'])
maruti_df.head()
# Out:
#             Prev Close    Open    High     Low   Last   Close    VWAP  \
# Date
# 2003-07-09      125.00  164.90  170.40  155.00  164.0  164.30  165.95
# 2003-07-10      164.30  167.00  168.70  164.50  167.0  167.00  166.74
# 2003-07-11      167.00  167.75  174.85  166.25  173.6  173.35  172.45
# 2003-07-14      173.35  174.25  179.25  174.25  178.6  177.95  177.91
# 2003-07-15      177.95  200.00  200.00  173.00  176.3  176.20  176.88
#
#               Volume      Turnover  Deliverable Volume  %Deliverble
# Date
# 2003-07-09  35164283  5.835528e+14           8537695.0       0.2428
# 2003-07-10  10464179  1.744820e+14           4363947.0       0.4170
# 2003-07-11  11740117  2.024622e+14           3014852.0       0.2568
# 2003-07-14   5982324  1.064313e+14           1949217.0       0.3258
# 2003-07-15   6173689  1.092001e+14           1307694.0       0.2118

# %%
maruti_df = maruti_df.dropna()

# %%
maruti_df.isnull().sum()
# Out:
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %% [markdown]
# #### Visualising Time Series Data

# %%
maruti_df['VWAP'].plot(figsize=(10,6),title='Maruti Stock Prices')
plt.ylabel('VWAP')
plt.show()

# %% [markdown]
# #### Manipulating Time Series Dataset

# %%
# Find minimum and maximum dates
print(maruti_df.index.max())
print(maruti_df.index.min())
# Out:
# 2021-04-30 00:00:00
# 2003-07-09 00:00:00

# %%
df_vwap = df[['Date','VWAP']]
df_vwap['Date'] = df_vwap['Date'].apply(pd.to_datetime)
df_vwap.set_index("Date", inplace = True)
df_vwap.head()
# Out:
# /tmp/ipykernel_46305/271265425.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vwap['Date'] = df_vwap['Date'].apply(pd.to_datetime)
#               VWAP
# Date
# 2003-07-09  165.95
# 2003-07-10  166.74
# 2003-07-11  172.45
# 2003-07-14  177.91
# 2003-07-15  176.88

# %% [markdown]
# #### Visualizing the Volume Weighted Average Price (VWAP)

# %% [markdown]
# ##### Visualizing using KDES

# %%
# Slicing on day
vwap_subset = df_vwap['2017-01-01':'2020-12-15']

# %%
ax = vwap_subset.plot(color='blue', fontsize=14)
ax.set_xlabel('Date')
ax.set_ylabel('VWAP')

ax.axvspan('2019-01-01','2019-01-31', color='red', alpha=0.3)
ax.axhspan(6500,7000, color='green',alpha=0.3)

plt.show()

# %% [markdown]
# ##### Visualizing using KDES

# %%
sns.kdeplot(df_vwap['VWAP'], shade=True)
# Out:
# /tmp/ipykernel_46305/128867843.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_vwap['VWAP'], shade=True)
# <Axes: xlabel='VWAP', ylabel='Density'>

# %% [markdown]
# ##### Visualizing using lineplots

# %%
# Visualising the VWAP 
df_vwap['VWAP'].plot(figsize=(16,8),title=' volume weighted average price')
# Out:
# <Axes: title={'center': ' volume weighted average price'}, xlabel='Date'>
